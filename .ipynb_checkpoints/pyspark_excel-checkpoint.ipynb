# %%
import pyspark.pandas as ps
from pyspark.sql import SparkSession
#https://towardsdatascience.com/run-pandas-as-fast-as-spark-f5eefe780c45

# %%
# For running Spark
spark = SparkSession.builder.appName("Pandas-Spark").getOrCreate()
# For running Pandas on top of Spark
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pandas-on-Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path='bn_buy_sell.csv'
# PANDAS-ON-SPARK
csv_df = ps.read_csv(path)

# %%
csv_df
# Out:
#                Date(UTC)     Market  Type         Price      Amount        Total       Fee Fee Coin
# 0    2022-01-03 04:48:17    USTBUSD   BUY      1.001800   149.00000   149.268200  0.149000      UST
# 1    2022-01-03 04:50:39    USTBUSD   BUY      1.001800     9.00000     9.016200  0.000013      BNB
# 2    2022-01-12 07:53:03    USTUSDT   BUY      1.000400   149.00000   149.059600  0.000244      BNB
# 3    2022-01-13 05:17:12    USTUSDT   BUY      1.000400   151.00000   151.060400  0.151000      UST
# 4    2022-01-17 16:23:15    USTUSDT   BUY      1.000700   179.00000   179.125300  0.000283      BNB
# 5    2022-01-25 11:05:00    USTUSDT   BUY      1.000000   101.00000   101.000000  0.000202      BNB
# 6    2022-01-27 10:54:32    USTUSDT   BUY      1.000200   299.00000   299.059800  0.299000      UST
# 7    2022-02-04 08:00:31    ETHUSDT   BUY   2815.000000     0.01770    49.825500  0.000099      BNB
# ...
